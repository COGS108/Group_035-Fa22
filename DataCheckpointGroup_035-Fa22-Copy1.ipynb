# %% [markdown]
# # COGS 108 - Data Checkpoint

# %% [markdown]
# # Names
#
# - Maxwell Fang
# - Long Le
# - Huy Trinh
# - Hasan Shaikh
# - Mohammed Master

# %% [markdown]
# <a id='research_question'></a>
# # Research Question

# %% [markdown]
# How does the spice level of instant ramen affect the star rating on the www.theramenrater.com in regards to preference across each country?

# %% [markdown]
# # Dataset(s)

# %% [markdown]
# *Fill in your dataset information here*
#
# (Copy this information for each dataset)
# - Dataset Name: Top Ramen Ratings 2022
# - Link to the dataset: https://www.kaggle.com/datasets/ankanhore545/top-ramen-ratings-2022
# - Number of observations: 4120
#
# 1-2 sentences describing each dataset.
#
# If you plan to use multiple datasets, add 1-2 sentences about how you plan to combine these datasets.

# %% [markdown]
# # Setup

# %%
from tqdm.notebook import tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict
import re

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'  # Higher resolution figures

# %%
## YOUR CODE HERE
ramen = pd.read_csv('ramen_rating.csv')
ramen
# Out:
#       Review #            Brand  \
# 0         4120              MIT
# 1         4119  Sapporo Ichiban
# 2         4118         Binh Tay
# 3         4117  Charming Couple
# 4         4116             immi
# ...        ...              ...
# 4115         5            Vifon
# 4116         4          Wai Wai
# 4117         3          Wai Wai
# 4118         2          Wai Wai
# 4119         1         Westbrae
#
#                                                 Variety Style        Country  \
# 0                              Shallot Sauce Dry Noodle  Pack         Taiwan
# 1                 Tonkotsu Ramen Japanese Style Noodles  Bowl  United States
# 2                                               Mi Kiwi  Bowl        Vietnam
# 3                    Biang Biang Scallion Chicken Sauce  Pack         Taiwan
# 4                      Tom Yum Shrimp Flavor Ramen Soup  Pack  United States
# ...                                                 ...   ...            ...
# 4115  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...  Bowl        Vietnam
# 4116                     Oriental Style Instant Noodles  Pack       Thailand
# 4117                                     Tom Yum Shrimp  Pack       Thailand
# 4118                               Tom Yum Chili Flavor  Pack       Thailand
# 4119                                         Miso Ramen  Pack  United States
#
#      Stars   T
# 0        3 NaN
# 1      4.5 NaN
# 2        3 NaN
# 3      4.5 NaN
# 4     2.75 NaN
# ...    ...  ..
# 4115   3.5 NaN
# 4116     1 NaN
# 4117     2 NaN
# 4118     2 NaN
# 4119   0.5 NaN
#
# [4120 rows x 7 columns]

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Describe your data cleaning steps here.

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION
df = ramen.drop(columns=['T','Review #'])
df.head()
# Out:
#              Brand                                Variety Style  \
# 0              MIT               Shallot Sauce Dry Noodle  Pack
# 1  Sapporo Ichiban  Tonkotsu Ramen Japanese Style Noodles  Bowl
# 2         Binh Tay                                Mi Kiwi  Bowl
# 3  Charming Couple     Biang Biang Scallion Chicken Sauce  Pack
# 4             immi       Tom Yum Shrimp Flavor Ramen Soup  Pack
#
#          Country Stars
# 0         Taiwan     3
# 1  United States   4.5
# 2        Vietnam     3
# 3         Taiwan   4.5
# 4  United States  2.75

# %%
spicy_levels = ['mild','medium','spicy','hot','fiery']
def spiciness(text):
    text= text.lower()
    for spice in spicy_levels:
        if spice in text:
            return spice
    return 'pepper free'

# 4059  Pack   India   2.5  pepper free  pepper free
# 4060  Pack   India     2  pepper free  pepper free
# 4061  Pack   India   3.5  pepper free         mild

# %%
popular_phrases.sort(key=lambda x: x[1],reverse = True)
popular_phrases
# Out:
# [('instant noodles', 298),
#  ('noodle soup', 178),
#  ('cup noodles', 161),
#  ('instant noodle', 134),
#  ('tom yum', 117),
#  ('chicken flavor', 104),
#  ('noodles with', 93),
#  ('ramen noodle', 84),
#  ('rice noodle', 77),
#  ('beef flavor', 74),
#  ('mi goreng', 73),
#  ('flavour instant', 73),
#  ('hot spicy', 71),
#  ('soy sauce', 68),
#  ('flavor ramen', 65),
#  ('chicken flavour', 63),
#  ('flavor instant', 57),
#  ('spicy beef', 55),
#  ('beef flavour', 55),
#  ('noodle with', 51),
#  ('tonkotsu ramen', 50),
#  ('rice vermicelli', 49),
#  ('miso ramen', 48),
#  ('noodles chicken', 48),
#  ('demae ramen', 48),
#  ('chow mein', 47),
#  ('ramen noodles', 45),
#  ('instant rice', 43),
#  ('bowl noodle', 41),
#  ('cup noodle', 40),
#  ('rice noodles', 40),
#  ('spicy chicken', 39),
#  ('curry flavour', 38),
#  ('shoyu ramen', 37),
#  ('style instant', 36),
#  ('artificial beef', 33),
#  ('fried noodles', 33),
#  ('seafood flavour', 33),
#  ('white curry', 33),
#  ('hot sour', 32),
#  ('pork flavor', 31),
#  ('tom yam', 31),
#  ('shio ramen', 30),
#  ('artificial chicken', 29),
#  ('top ramen', 29),
#  ('sauce flavor', 28),
#  ('sesame oil', 28),
#  ('pork flavour', 26),
#  ('penang white', 26),
#  ('oriental style', 26),
#  ('japanese style', 25),
#  ('noodles spicy', 25),
#  ('spicy seafood', 25),
#  ('kung fu', 25),
#  ('noodles tom', 25),
#  ('yum shrimp', 22),
#  ('with soup', 22),
#  ('artificial pork', 22),
#  ('noodles beef', 22),
#  ('curry noodle', 22),
#  ('soup base', 22),
#  ('shrimp flavor', 21),
#  ('ramen spicy', 21),
#  ('non fried', 21),
#  ('noodle spicy', 21),
#  ('demae iccho', 21),
#  ('seafood flavor', 20),
#  ('black pepper', 20),
#  ('shrimp tom', 20),
#  ('yum flavour', 20),
#  ('buldak bokkeummyun', 20),
#  ('sabor a', 20),
#  ('dried noodles', 19),
#  ('noodles artificial', 19),
#  ('korean style', 19),
#  ('noodles shrimp', 19),
#  ('noodle bowl', 19),
#  ('spicy flavor', 19),
#  ('big bowl', 19),
#  ('xo sauce', 18),
#  ('soup flavour', 18),
#  ('mi segera', 18),
#  ('bowl noodles', 18),
#  ('ramen soup', 17),
#  ('spicy shrimp', 17),
#  ('shrimp flavour', 17),
#  ('crab flavour', 17),
#  ('creamy tom', 17),
#  ('green curry', 17),
#  ('noodles hot', 17),
#  ('oriental noodles', 17),
#  ('sesame sauce', 17),
#  ('minced pork', 16),
#  ('instant lunch', 16),
#  ('noodles vegetable', 16),
#  ('braised beef', 16),
#  ('noodle king', 16),
#  ('rasa ayam', 16),
#  ('super noodles', 16),
#  ('curry udon', 15),
#  ('fried noodle', 15),
#  ('spicy flavour', 15),
#  ('flavour noodle', 15),
#  ('minute noodles', 15),
#  ('south korean', 15),
#  ('dry noodle', 14),
#  ('stir fry', 14),
#  ('curry flavor', 14),
#  ('noodles soup', 14),
#  ('yum goong', 14),
#  ('pad thai', 14),
#  ('laksa flavour', 14),
#  ('spicy hot', 14),
#  ('sopa nissin', 14),
#  ('style noodles', 13),
#  ('hot chicken', 13),
#  ('soup chicken', 13),
#  ('instant ramen', 13),
#  ('beef noodle', 13),
#  ('instant cup', 13),
#  ('hot pot', 13),
#  ('kitsune udon', 13),
#  ('beef with', 13),
#  ('pepper crab', 13),
#  ('artificial spicy', 13),
#  ('dry noodles', 13),
#  ('kuah rasa', 13),
#  ('taste of', 13),
#  ('big cup', 13),
#  ('spicy miso', 12),
#  ('stir fried', 12),
#  ('u f', 12),
#  ('f o', 12),
#  ('kimchi ramen', 12),
#  ('sichuan pepper', 12),
#  ('tonkotsu flavour', 12),
#  ('with spicy', 12),
#  ('la mian', 12),
#  ('vegetable flavour', 12),
#  ('chicken curry', 12),
#  ('noodles curry', 12),
#  ('soybean paste', 12),
#  ('new recipe', 12),
#  ('flavor noodle', 12),
#  ('noodles seafood', 12),
#  ('noodle snack', 12),
#  ('fu artificial', 12),
#  ('style noodle', 11),
#  ('sauce ramen', 11),
#  ('shrimp creamy', 11),
#  ('tempura udon', 11),
#  ('asian style', 11),
#  ('original flavor', 11),
#  ('chicken soup', 11),
#  ('prawn soup', 11),
#  ('penang red', 11),
#  ('instant vermicelli', 11),
#  ('yum kung', 11),
#  ('premium noodle', 11),
#  ('pancit canton', 11),
#  ('sweet potato', 11),
#  ('shin ramyun', 11),
#  ('malaysia penang', 11)]

# %%
# extracting spiciness from text
# cleaning th variety string
variety_list = (df['Variety'].str.lower()
                .str.replace('[^a-zA-Z]', ' ', regex=True)
                .str.replace(' +', ' ', regex=True).values)

# finding the most popular phrases to catagorize
pairs_dict = {}
for i in variety_list:
    words = i.split()
    for j in range(len(words) - 1):
        pair = words[j] + ' ' + words[j+1]
        if pair in pairs_dict:
            pairs_dict[pair] += 1
        else:
            pairs_dict[pair] = 1
            
popular_phrases = [(i, pairs_dict[i]) for i in pairs_dict if pairs_dict[i] > 10]
popular_phrases
# Out:
# [('dry noodle', 14),
#  ('tonkotsu ramen', 50),
#  ('japanese style', 25),
#  ('style noodles', 13),
#  ('tom yum', 117),
#  ('yum shrimp', 22),
#  ('shrimp flavor', 21),
#  ('flavor ramen', 65),
#  ('ramen soup', 17),
#  ('rice noodle', 77),
#  ('chicken flavor', 104),
#  ('seafood flavor', 20),
#  ('dried noodles', 19),
#  ('spicy beef', 55),
#  ('beef flavor', 74),
#  ('mi goreng', 73),
#  ('black pepper', 20),
#  ('hot spicy', 71),
#  ('soy sauce', 68),
#  ('ramen noodle', 84),
#  ('noodle soup', 178),
#  ('instant noodles', 298),
#  ('noodles artificial', 19),
#  ('artificial beef', 33),
#  ('chow mein', 47),
#  ('cup noodle', 40),
#  ('spicy shrimp', 17),
#  ('rice noodles', 40),
#  ('spicy miso', 12),
#  ('miso ramen', 48),
#  ('instant rice', 43),
#  ('rice vermicelli', 49),
#  ('shoyu ramen', 37),
#  ('cup noodles', 161),
#  ('stir fry', 14),
#  ('curry flavor', 14),
#  ('sauce flavor', 28),
#  ('fried noodles', 33),
#  ('stir fried', 12),
#  ('noodles with', 93),
#  ('korean style', 19),
#  ('noodle with', 51),
#  ('ramen spicy', 21),
#  ('style noodle', 11),
#  ('sauce ramen', 11),
#  ('minced pork', 16),
#  ('pork flavor', 31),
#  ('spicy chicken', 39),
#  ('shio ramen', 30),
#  ('noodles chicken', 48),
#  ('chicken flavour', 63),
#  ('shrimp tom', 20),
#  ('instant lunch', 16),
#  ('artificial chicken', 29),
#  ('flavor instant', 57),
#  ('instant noodle', 134),
#  ('shrimp flavour', 17),
#  ('flavour instant', 73),
#  ('crab flavour', 17),
#  ('hot chicken', 13),
#  ('noodles vegetable', 16),
#  ('shrimp creamy', 11),
#  ('creamy tom', 17),
#  ('yum flavour', 20),
#  ('demae ramen', 48),
#  ('xo sauce', 18),
#  ('seafood flavour', 33),
#  ('soup chicken', 13),
#  ('u f', 12),
#  ('f o', 12),
#  ('noodles soup', 14),
#  ('instant ramen', 13),
#  ('beef flavour', 55),
#  ('tempura udon', 11),
#  ('braised beef', 16),
#  ('beef noodle', 13),
#  ('with soup', 22),
#  ('kimchi ramen', 12),
#  ('top ramen', 29),
#  ('asian style', 11),
#  ('sesame oil', 28),
#  ('ramen noodles', 45),
#  ('noodles shrimp', 19),
#  ('noodle bowl', 19),
#  ('noodles spicy', 25),
#  ('artificial pork', 22),
#  ('pork flavour', 26),
#  ('original flavor', 11),
#  ('sichuan pepper', 12),
#  ('instant cup', 13),
#  ('hot pot', 13),
#  ('tonkotsu flavour', 12),
#  ('chicken soup', 11),
#  ('soup flavour', 18),
#  ('with spicy', 12),
#  ('spicy seafood', 25),
#  ('spicy flavor', 19),
#  ('bowl noodle', 41),
#  ('prawn soup', 11),
#  ('la mian', 12),
#  ('kitsune udon', 13),
#  ('penang red', 11),
#  ('yum goong', 14),
#  ('hot sour', 32),
#  ('instant vermicelli', 11),
#  ('non fried', 21),
#  ('vegetable flavour', 12),
#  ('green curry', 17),
#  ('pad thai', 14),
#  ('noodles hot', 17),
#  ('curry flavour', 38),
#  ('noodles beef', 22),
#  ('chicken curry', 12),
#  ('mi segera', 18),
#  ('penang white', 26),
#  ('white curry', 33),
#  ('curry noodle', 22),
#  ('style instant', 36),
#  ('noodles curry', 12),
#  ('curry udon', 15),
#  ('fried noodle', 15),
#  ('beef with', 13),
#  ('yum kung', 11),
#  ('noodle king', 16),
#  ('soybean paste', 12),
#  ('laksa flavour', 14),
#  ('pepper crab', 13),
#  ('spicy flavour', 15),
#  ('artificial spicy', 13),
#  ('noodle spicy', 21),
#  ('oriental noodles', 17),
#  ('premium noodle', 11),
#  ('spicy hot', 14),
#  ('new recipe', 12),
#  ('oriental style', 26),
#  ('dry noodles', 13),
#  ('big bowl', 19),
#  ('flavour noodle', 15),
#  ('kung fu', 25),
#  ('noodles tom', 25),
#  ('pancit canton', 11),
#  ('sesame sauce', 17),
#  ('sweet potato', 11),
#  ('kuah rasa', 13),
#  ('rasa ayam', 16),
#  ('flavor noodle', 12),
#  ('buldak bokkeummyun', 20),
#  ('noodles seafood', 12),
#  ('shin ramyun', 11),
#  ('noodle snack', 12),
#  ('tom yam', 31),
#  ('minute noodles', 15),
#  ('taste of', 13),
#  ('demae iccho', 21),
#  ('soup base', 22),
#  ('sopa nissin', 14),
#  ('sabor a', 20),
#  ('bowl noodles', 18),
#  ('big cup', 13),
#  ('malaysia penang', 11),
#  ('super noodles', 16),
#  ('south korean', 15),
#  ('fu artificial', 12)]

# %%
spiciness_dict = {
    'tonkotsu ramen': 'mild',
    'japanese style': 'mild',
    'tom yum': 'hot',
    'chicken flavor': 'mild',
    'seafood flavor': 'mild',
    'beef flavor': 'mild',
    'mi goreng': 'mild',
    'black pepper': 'hot',
    'soy sauce': 'mild',
    'chow mein': 'mild', 
    'shoyu': 'mild',
    'korean': 'hot',
    'pork flavor': 'mild',
    'shio': 'mild', 
    'shrimp flavour':'mild', 
    'crab flavour':'mild',
    'seafood flavour': 'mild',
    'creamy' : 'mild',
    'demae': 'mild',
    'xo sauce': 'mild',
    'seafood flavour': 'mild',
    'udon': 'mild',
    'tempura': 'mild',
    'kimchi': 'hot',
    'sesame oil': 'mild',
    'artificial pork': 'mild',
    'sichuan': 'hot',
    'tonkotsu': 'mild',
    'chicken soup': 'mild',
    'mi segera': 'mild',
    'penang white': 'hot',
    'curry': 'mild',
    'yum kung': 'hot',
    'soy paste': 'mild',
    'laksa': 'hot',
    'artificial': 'mild',
    'pancit canton': 'mild',
    'sweet potato': 'mild',
    'kuah rasa': 'mild',
    'rasa ayam': 'mild',
    'buldak': 'hot',
    'bokkeummyun': 'hot',
    'shin ramyun': 'hot',
    'tom yam': 'hot',
    'demae iccho': 'mild',
    'sopa nissin': 'mild',
    'malaysia penang': 'hot',
    'south korean': 'hot',
    'fiery': 'hot'
}


spicy_levels = ['mild','medium','spicy','hot']
def spiciness(text):
    # catch if the spciniess is directly in the text
    text = re.sub('r[^a-zA-Z]', ' ', text.lower())
    text = re.sub(' +', ' ', text)
    for spice in spicy_levels:
        if spice in text:
            return spice
    
    # catch if the spiciness is implied in the text 
    words = text.split()
    for j in range(len(words) - 1):
        pair = words[j] + ' ' + words[j+1]
        if pair in spiciness_dict:
            return spiciness_dict[pair]
    return 'pepper free'


df['spiciness_2'] = df['Variety'].apply(spiciness)
df['spiciness_2'].value_counts()
# Out:
# pepper free    2834
# mild            526
# spicy           446
# hot             314
# Name: spiciness_2, dtype: int64

# %%
# Out:
#                 Brand                                            Variety  \
# 0                 MIT                           Shallot Sauce Dry Noodle
# 1     Sapporo Ichiban              Tonkotsu Ramen Japanese Style Noodles
# 2            Binh Tay                                            Mi Kiwi
# 3     Charming Couple                 Biang Biang Scallion Chicken Sauce
# 4                immi                   Tom Yum Shrimp Flavor Ramen Soup
# ...               ...                                                ...
# 4115            Vifon  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...
# 4116          Wai Wai                     Oriental Style Instant Noodles
# 4117          Wai Wai                                     Tom Yum Shrimp
# 4118          Wai Wai                               Tom Yum Chili Flavor
# 4119         Westbrae                                         Miso Ramen
#
#      Style        Country Stars    spiciness  spiciness_2
# 0     Pack         Taiwan     3  pepper free  pepper free
# 1     Bowl  United States   4.5  pepper free         mild
# 2     Bowl        Vietnam     3  pepper free  pepper free
# 3     Pack         Taiwan   4.5  pepper free  pepper free
# 4     Pack  United States  2.75  pepper free          hot
# ...    ...            ...   ...          ...          ...
# 4115  Bowl        Vietnam   3.5  pepper free  pepper free
# 4116  Pack       Thailand     1  pepper free  pepper free
# 4117  Pack       Thailand     2  pepper free          hot
# 4118  Pack       Thailand     2  pepper free          hot
# 4119  Pack  United States   0.5  pepper free  pepper free
#
# [4120 rows x 7 columns]

# %% [markdown]
# # separate by region

# %% [markdown]
# 'https://worldpopulationreview.com/country-rankings/list-of-countries-by-continent'

# %%
continent = pd.read_csv('country_by_continent.csv')
continent['country'] = continent['country'].str.lower().str.replace(' ','')
df['country'] =  df['Country'].str.lower().str.replace(' ','')
continent
# Out:
#          country      continent
# 0        algeria         Africa
# 1         angola         Africa
# 2          benin         Africa
# 3       botswana         Africa
# 4    burkinafaso         Africa
# ..           ...            ...
# 229     paraguay  South America
# 230         peru  South America
# 231     suriname  South America
# 232      uruguay  South America
# 233    venezuela  South America
#
# [234 rows x 2 columns]

# %%
new_df = pd.merge(df, continent, on="country")
new_df = new_df.drop(columns=['country'])
new_df
# Out:
#                 Brand                                     Variety Style  \
# 0                 MIT                    Shallot Sauce Dry Noodle  Pack
# 1     Charming Couple          Biang Biang Scallion Chicken Sauce  Pack
# 2        Hi Lai Foods        Lai Noodle Vegan Sesame Paste Flavor  Pack
# 3             Ve Wong             Artificial Peppered Beef Flavor  Pack
# 4             iNoodle                Flat Noodle Soy Sauce Flavor  Pack
# ...               ...                                         ...   ...
# 4022           Nissin   Sabor A Pollo Sopa Instantánea Con Fideos  Pack
# 4023           Nissin                 Cup Noodles Sabor A Gallina   Cup
# 4024           Nissin   Sabor A Carne Sopa Instantánea Con Fideos  Pack
# 4025           Baltix  Instant Noodles With Chicken Flavour Broth  Pack
# 4026           Baltix     Instant Noodles With Beef Flavour Broth  Pack
#
#        Country Stars    spiciness  spiciness_2      continent
# 0       Taiwan     3  pepper free  pepper free           Asia
# 1       Taiwan   4.5  pepper free  pepper free           Asia
# 2       Taiwan     5  pepper free  pepper free           Asia
# 3       Taiwan   3.5  pepper free         mild           Asia
# 4       Taiwan  3.25  pepper free         mild           Asia
# ...        ...   ...          ...          ...            ...
# 4022  Colombia  3.25  pepper free  pepper free  South America
# 4023  Colombia   3.5  pepper free  pepper free  South America
# 4024  Colombia  3.75  pepper free  pepper free  South America
# 4025   Estonia  3.75  pepper free  pepper free         Europe
# 4026   Estonia  3.25  pepper free  pepper free         Europe
#
# [4027 rows x 8 columns]
